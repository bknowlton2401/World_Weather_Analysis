# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress

# %%
# Create list for weather data
city_data = []

# Create counters
record_count = 1
set_count = 1

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2192/3820621332.py in <module>
#       1 # Starting URL for Weather Map API Call.
# ----> 2 url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#
# NameError: name 'weather_api_key' is not defined

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# %%
# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 747

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_weather_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | yenagoa
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | kalat
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | imbituba
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | san javier
# Processing Record 11 of Set 1 | saint george
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | vanavara
# Processing Record 18 of Set 1 | tautira
# Processing Record 19 of Set 1 | waipawa
# Processing Record 20 of Set 1 | troitsko-pechorsk
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | burnie
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | roma
# Processing Record 27 of Set 1 | port hardy
# Processing Record 28 of Set 1 | coari
# Processing Record 29 of Set 1 | cockburn town
# Processing Record 30 of Set 1 | leningradskiy
# Processing Record 31 of Set 1 | esperance
# Processing Record 32 of Set 1 | bubaque
# Processing Record 33 of Set 1 | fukuma
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | auly
# Processing Record 38 of Set 1 | tabou
# Processing Record 39 of Set 1 | weston
# Processing Record 40 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 1 | dudinka
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | trinidad
# Processing Record 45 of Set 1 | severo-kurilsk
# Processing Record 46 of Set 1 | guerrero negro
# Processing Record 47 of Set 1 | coquimbo
# Processing Record 48 of Set 1 | beringovskiy
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | straumen
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | bereda
# Processing Record 7 of Set 2 | vostok
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | foumbot
# Processing Record 10 of Set 2 | formosa do rio preto
# Processing Record 11 of Set 2 | abu kamal
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | bandarbeyla
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | accrington
# Processing Record 18 of Set 2 | belmonte
# Processing Record 19 of Set 2 | altay
# Processing Record 20 of Set 2 | la roche-sur-yon
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | hurghada
# Processing Record 23 of Set 2 | salalah
# Processing Record 24 of Set 2 | geraldton
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | sayyan
# Processing Record 27 of Set 2 | faanui
# Processing Record 28 of Set 2 | souillac
# Processing Record 29 of Set 2 | zlatoustovsk
# City not found. Skipping...
# Processing Record 30 of Set 2 | guider
# Processing Record 31 of Set 2 | lukovetskiy
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | cartagena
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | port-gentil
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | sergeyevka
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | maldonado
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | hue
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | thinadhoo
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | nizwa
# Processing Record 2 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 3 | riohacha
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | nemuro
# Processing Record 6 of Set 3 | port keats
# Processing Record 7 of Set 3 | sola
# Processing Record 8 of Set 3 | trofors
# Processing Record 9 of Set 3 | yurla
# Processing Record 10 of Set 3 | portland
# Processing Record 11 of Set 3 | west wendover
# Processing Record 12 of Set 3 | whitehorse
# Processing Record 13 of Set 3 | yellowknife
# Processing Record 14 of Set 3 | grootfontein
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | rocha
# Processing Record 17 of Set 3 | pevek
# Processing Record 18 of Set 3 | haines junction
# Processing Record 19 of Set 3 | nelson
# Processing Record 20 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 3 | riyadh
# Processing Record 22 of Set 3 | taua
# Processing Record 23 of Set 3 | hilo
# Processing Record 24 of Set 3 | sibolga
# Processing Record 25 of Set 3 | kubrat
# Processing Record 26 of Set 3 | wanning
# Processing Record 27 of Set 3 | acajutla
# Processing Record 28 of Set 3 | victoria
# Processing Record 29 of Set 3 | vilhena
# Processing Record 30 of Set 3 | nome
# Processing Record 31 of Set 3 | henties bay
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | karwar
# Processing Record 34 of Set 3 | shaumiani
# Processing Record 35 of Set 3 | pinhao
# Processing Record 36 of Set 3 | margate
# Processing Record 37 of Set 3 | kirksville
# Processing Record 38 of Set 3 | opunake
# Processing Record 39 of Set 3 | barrow
# Processing Record 40 of Set 3 | isangel
# Processing Record 41 of Set 3 | gunib
# Processing Record 42 of Set 3 | paracuru
# Processing Record 43 of Set 3 | ati
# Processing Record 44 of Set 3 | manitouwadge
# Processing Record 45 of Set 3 | xinxiang
# Processing Record 46 of Set 3 | hithadhoo
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | tasiilaq
# Processing Record 49 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 3 | opuwo
# Processing Record 1 of Set 4 | ixtapa
# Processing Record 2 of Set 4 | tabas
# Processing Record 3 of Set 4 | atherton
# Processing Record 4 of Set 4 | saint-georges
# Processing Record 5 of Set 4 | kahului
# Processing Record 6 of Set 4 | usumatlan
# Processing Record 7 of Set 4 | musafirkhana
# Processing Record 8 of Set 4 | flin flon
# Processing Record 9 of Set 4 | saint-augustin
# Processing Record 10 of Set 4 | kalemie
# Processing Record 11 of Set 4 | port hedland
# Processing Record 12 of Set 4 | ponta delgada
# Processing Record 13 of Set 4 | bilma
# Processing Record 14 of Set 4 | hongjiang
# Processing Record 15 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 4 | klyuchi
# Processing Record 17 of Set 4 | atuona
# Processing Record 18 of Set 4 | carnarvon
# Processing Record 19 of Set 4 | longyearbyen
# Processing Record 20 of Set 4 | san juan de uraba
# Processing Record 21 of Set 4 | fort oglethorpe
# Processing Record 22 of Set 4 | jamestown
# Processing Record 23 of Set 4 | santa isabel do rio negro
# Processing Record 24 of Set 4 | grand gaube
# Processing Record 25 of Set 4 | cidreira
# Processing Record 26 of Set 4 | galesong
# Processing Record 27 of Set 4 | fez
# Processing Record 28 of Set 4 | brigantine
# Processing Record 29 of Set 4 | husavik
# Processing Record 30 of Set 4 | bagalkot
# Processing Record 31 of Set 4 | blackwater
# Processing Record 32 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | chuy
# Processing Record 35 of Set 4 | shimoda
# Processing Record 36 of Set 4 | puerto ayora
# Processing Record 37 of Set 4 | vila franca do campo
# Processing Record 38 of Set 4 | san ignacio
# Processing Record 39 of Set 4 | kenai
# Processing Record 40 of Set 4 | sao francisco do sul
# Processing Record 41 of Set 4 | puerto montt
# Processing Record 42 of Set 4 | nantucket
# Processing Record 43 of Set 4 | ancud
# Processing Record 44 of Set 4 | blackpool
# Processing Record 45 of Set 4 | bom jesus
# Processing Record 46 of Set 4 | san patricio
# Processing Record 47 of Set 4 | turochak
# Processing Record 48 of Set 4 | sampit
# Processing Record 49 of Set 4 | winslow
# Processing Record 50 of Set 4 | anzio
# Processing Record 1 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 5 | leshukonskoye
# Processing Record 3 of Set 5 | airai
# Processing Record 4 of Set 5 | minot
# Processing Record 5 of Set 5 | anadyr
# Processing Record 6 of Set 5 | cotonou
# Processing Record 7 of Set 5 | lavrentiya
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | fasano
# Processing Record 10 of Set 5 | bilibino
# Processing Record 11 of Set 5 | fortuna
# Processing Record 12 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 13 of Set 5 | wawa
# Processing Record 14 of Set 5 | zhanaozen
# Processing Record 15 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 5 | saint-pierre
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | fort nelson
# Processing Record 19 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 5 | sitka
# Processing Record 21 of Set 5 | touros
# Processing Record 22 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 5 | porto belo
# Processing Record 24 of Set 5 | sambava
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | porgera
# Processing Record 27 of Set 5 | inhambane
# Processing Record 28 of Set 5 | juegang
# Processing Record 29 of Set 5 | hanumangarh
# Processing Record 30 of Set 5 | duncan
# Processing Record 31 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 32 of Set 5 | karratha
# Processing Record 33 of Set 5 | visby
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | bima
# Processing Record 36 of Set 5 | muros
# Processing Record 37 of Set 5 | adrar
# Processing Record 38 of Set 5 | buluang
# Processing Record 39 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 5 | rio gallegos
# Processing Record 41 of Set 5 | mahebourg
# Processing Record 42 of Set 5 | saldanha
# Processing Record 43 of Set 5 | saskylakh
# Processing Record 44 of Set 5 | odweyne
# Processing Record 45 of Set 5 | huetamo
# City not found. Skipping...
# Processing Record 46 of Set 5 | nysa
# Processing Record 47 of Set 5 | begunitsy
# Processing Record 48 of Set 5 | pasni
# Processing Record 49 of Set 5 | zlobin
# Processing Record 50 of Set 5 | arkhangelsk
# Processing Record 1 of Set 6 | bambous virieux
# Processing Record 2 of Set 6 | flinders
# Processing Record 3 of Set 6 | minnedosa
# Processing Record 4 of Set 6 | lorengau
# Processing Record 5 of Set 6 | nueva loja
# Processing Record 6 of Set 6 | pangnirtung
# Processing Record 7 of Set 6 | ilulissat
# Processing Record 8 of Set 6 | champerico
# Processing Record 9 of Set 6 | padang
# Processing Record 10 of Set 6 | dingle
# Processing Record 11 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | cap malheureux
# Processing Record 13 of Set 6 | los llanos de aridane
# Processing Record 14 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 6 | klaksvik
# Processing Record 17 of Set 6 | puerto carreno
# Processing Record 18 of Set 6 | srednekolymsk
# Processing Record 19 of Set 6 | panzhihua
# Processing Record 20 of Set 6 | bardiyah
# Processing Record 21 of Set 6 | avera
# Processing Record 22 of Set 6 | torbay
# Processing Record 23 of Set 6 | faya
# Processing Record 24 of Set 6 | tuatapere
# Processing Record 25 of Set 6 | moree
# Processing Record 26 of Set 6 | galveston
# Processing Record 27 of Set 6 | sabha
# Processing Record 28 of Set 6 | bermeo
# Processing Record 29 of Set 6 | yorkton
# Processing Record 30 of Set 6 | chico
# Processing Record 31 of Set 6 | itoman
# Processing Record 32 of Set 6 | banjar
# Processing Record 33 of Set 6 | bukachacha
# Processing Record 34 of Set 6 | sao filipe
# Processing Record 35 of Set 6 | venado tuerto
# Processing Record 36 of Set 6 | taoudenni
# Processing Record 37 of Set 6 | magdalena
# Processing Record 38 of Set 6 | susangerd
# Processing Record 39 of Set 6 | lasa
# Processing Record 40 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 41 of Set 6 | banda aceh
# Processing Record 42 of Set 6 | camopi
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | hualmay
# Processing Record 45 of Set 6 | tarut
# Processing Record 46 of Set 6 | razole
# Processing Record 47 of Set 6 | meulaboh
# Processing Record 48 of Set 6 | dillon
# Processing Record 49 of Set 6 | luderitz
# Processing Record 50 of Set 6 | marstal
# Processing Record 1 of Set 7 | mendeleyevo
# Processing Record 2 of Set 7 | baturaja
# Processing Record 3 of Set 7 | kabompo
# Processing Record 4 of Set 7 | svetlogorsk
# Processing Record 5 of Set 7 | palmer
# Processing Record 6 of Set 7 | koslan
# Processing Record 7 of Set 7 | clyde river
# Processing Record 8 of Set 7 | luganville
# Processing Record 9 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 7 | paamiut
# Processing Record 11 of Set 7 | vestmannaeyjar
# Processing Record 12 of Set 7 | sao sebastiao
# Processing Record 13 of Set 7 | linares
# Processing Record 14 of Set 7 | tocopilla
# Processing Record 15 of Set 7 | sao gabriel da cachoeira
# Processing Record 16 of Set 7 | shenjiamen
# Processing Record 17 of Set 7 | walvis bay
# Processing Record 18 of Set 7 | kisangani
# Processing Record 19 of Set 7 | berlevag
# Processing Record 20 of Set 7 | ostrovnoy
# Processing Record 21 of Set 7 | houston
# Processing Record 22 of Set 7 | mackay
# Processing Record 23 of Set 7 | port antonio
# Processing Record 24 of Set 7 | evensk
# Processing Record 25 of Set 7 | huazolotitlan
# City not found. Skipping...
# Processing Record 26 of Set 7 | gondanglegi
# Processing Record 27 of Set 7 | nuh
# Processing Record 28 of Set 7 | bose
# Processing Record 29 of Set 7 | simpang
# Processing Record 30 of Set 7 | marawi
# Processing Record 31 of Set 7 | bodegraven
# Processing Record 32 of Set 7 | verkhoyansk
# Processing Record 33 of Set 7 | ambilobe
# Processing Record 34 of Set 7 | maracas
# Processing Record 35 of Set 7 | mirnyy
# Processing Record 36 of Set 7 | solnechnyy
# Processing Record 37 of Set 7 | jupiter
# Processing Record 38 of Set 7 | nouadhibou
# Processing Record 39 of Set 7 | constantine
# Processing Record 40 of Set 7 | kavaratti
# Processing Record 41 of Set 7 | gazanjyk
# Processing Record 42 of Set 7 | dhaka
# Processing Record 43 of Set 7 | codrington
# Processing Record 44 of Set 7 | colares
# Processing Record 45 of Set 7 | amapa
# Processing Record 46 of Set 7 | medea
# Processing Record 47 of Set 7 | azul
# Processing Record 48 of Set 7 | prambanan
# City not found. Skipping...
# Processing Record 49 of Set 7 | katsuura
# Processing Record 50 of Set 7 | havelock
# Processing Record 1 of Set 8 | maues
# Processing Record 2 of Set 8 | apiai
# Processing Record 3 of Set 8 | bjornevatn
# Processing Record 4 of Set 8 | gazojak
# Processing Record 5 of Set 8 | debno
# Processing Record 6 of Set 8 | ariano irpino
# Processing Record 7 of Set 8 | aginskoye
# Processing Record 8 of Set 8 | vanimo
# Processing Record 9 of Set 8 | muisne
# Processing Record 10 of Set 8 | puerto ayacucho
# Processing Record 11 of Set 8 | dolores
# Processing Record 12 of Set 8 | hofn
# Processing Record 13 of Set 8 | lazaro cardenas
# Processing Record 14 of Set 8 | cherskiy
# Processing Record 15 of Set 8 | gawler
# Processing Record 16 of Set 8 | imuris
# Processing Record 17 of Set 8 | praia da vitoria
# Processing Record 18 of Set 8 | tuy hoa
# Processing Record 19 of Set 8 | muzhi
# Processing Record 20 of Set 8 | broome
# Processing Record 21 of Set 8 | kruisfontein
# Processing Record 22 of Set 8 | alice springs
# Processing Record 23 of Set 8 | kirakira
# Processing Record 24 of Set 8 | morgantown
# Processing Record 25 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 26 of Set 8 | doembang nangbuat
# Processing Record 27 of Set 8 | taltal
# Processing Record 28 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 8 | comodoro rivadavia
# Processing Record 30 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 8 | grindavik
# Processing Record 32 of Set 8 | provideniya
# Processing Record 33 of Set 8 | stephenville
# Processing Record 34 of Set 8 | otorohanga
# Processing Record 35 of Set 8 | kenmare
# Processing Record 36 of Set 8 | letlhakane
# Processing Record 37 of Set 8 | deputatskiy
# Processing Record 38 of Set 8 | chapais
# Processing Record 39 of Set 8 | erenhot
# Processing Record 40 of Set 8 | anchorage
# Processing Record 41 of Set 8 | augustow
# Processing Record 42 of Set 8 | mayumba
# Processing Record 43 of Set 8 | tura
# Processing Record 44 of Set 8 | paignton
# Processing Record 45 of Set 8 | siderno
# Processing Record 46 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 48 of Set 8 | tual
# Processing Record 49 of Set 8 | san quintin
# Processing Record 50 of Set 8 | beloha
# Processing Record 1 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 9 | audru
# Processing Record 3 of Set 9 | honiara
# Processing Record 4 of Set 9 | tumut
# Processing Record 5 of Set 9 | svetlyy
# Processing Record 6 of Set 9 | recife
# Processing Record 7 of Set 9 | romanovo
# Processing Record 8 of Set 9 | baykit
# Processing Record 9 of Set 9 | la fria
# Processing Record 10 of Set 9 | pisco
# Processing Record 11 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 9 | balkhash
# Processing Record 13 of Set 9 | port lincoln
# Processing Record 14 of Set 9 | whyalla
# Processing Record 15 of Set 9 | atasu
# Processing Record 16 of Set 9 | darab
# Processing Record 17 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 18 of Set 9 | sechura
# Processing Record 19 of Set 9 | villamontes
# Processing Record 20 of Set 9 | hirara
# Processing Record 21 of Set 9 | tres passos
# Processing Record 22 of Set 9 | mount isa
# Processing Record 23 of Set 9 | andilamena
# Processing Record 24 of Set 9 | yerbogachen
# Processing Record 25 of Set 9 | iquique
# Processing Record 26 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 27 of Set 9 | sinnamary
# Processing Record 28 of Set 9 | amuntai
# Processing Record 29 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 30 of Set 9 | bonthe
# Processing Record 31 of Set 9 | kieta
# Processing Record 32 of Set 9 | bobon
# Processing Record 33 of Set 9 | presidente medici
# Processing Record 34 of Set 9 | araceli
# Processing Record 35 of Set 9 | aktau
# Processing Record 36 of Set 9 | ngong
# Processing Record 37 of Set 9 | port blair
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | synya
# Processing Record 40 of Set 9 | bac lieu
# Processing Record 41 of Set 9 | msowero
# Processing Record 42 of Set 9 | balabac
# Processing Record 43 of Set 9 | yanam
# Processing Record 44 of Set 9 | woodward
# Processing Record 45 of Set 9 | comrat
# Processing Record 46 of Set 9 | kirkwall
# Processing Record 47 of Set 9 | wakkanai
# Processing Record 48 of Set 9 | anloga
# Processing Record 49 of Set 9 | bulgan
# Processing Record 50 of Set 9 | elizabeth city
# Processing Record 1 of Set 10 | juazeiro
# Processing Record 2 of Set 10 | hami
# Processing Record 3 of Set 10 | lizzano
# Processing Record 4 of Set 10 | vila velha
# Processing Record 5 of Set 10 | baie-comeau
# Processing Record 6 of Set 10 | saint-joseph
# Processing Record 7 of Set 10 | taldan
# Processing Record 8 of Set 10 | felipe carrillo puerto
# Processing Record 9 of Set 10 | nabire
# Processing Record 10 of Set 10 | piacabucu
# Processing Record 11 of Set 10 | prince rupert
# Processing Record 12 of Set 10 | jimma
# Processing Record 13 of Set 10 | fairbanks
# Processing Record 14 of Set 10 | snezhnogorsk
# Processing Record 15 of Set 10 | mehran
# Processing Record 16 of Set 10 | ossora
# Processing Record 17 of Set 10 | gimli
# Processing Record 18 of Set 10 | beipiao
# Processing Record 19 of Set 10 | vao
# Processing Record 20 of Set 10 | tiznit
# Processing Record 21 of Set 10 | vestmanna
# Processing Record 22 of Set 10 | ko samui
# Processing Record 23 of Set 10 | oranjemund
# Processing Record 24 of Set 10 | samarai
# Processing Record 25 of Set 10 | ulcinj
# Processing Record 26 of Set 10 | katherine
# Processing Record 27 of Set 10 | anori
# Processing Record 28 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 29 of Set 10 | lhokseumawe
# Processing Record 30 of Set 10 | vikesa
# Processing Record 31 of Set 10 | monticello
# Processing Record 32 of Set 10 | gueret
# Processing Record 33 of Set 10 | asau
# Processing Record 34 of Set 10 | salinopolis
# Processing Record 35 of Set 10 | zhigansk
# Processing Record 36 of Set 10 | dwarka
# Processing Record 37 of Set 10 | niono
# Processing Record 38 of Set 10 | illapel
# Processing Record 39 of Set 10 | nyeri
# Processing Record 40 of Set 10 | dedza
# Processing Record 41 of Set 10 | wajir
# Processing Record 42 of Set 10 | spring hill
# Processing Record 43 of Set 10 | pakxan
# Processing Record 44 of Set 10 | maryville
# Processing Record 45 of Set 10 | harper
# Processing Record 46 of Set 10 | richards bay
# Processing Record 47 of Set 10 | kholodnyy
# Processing Record 48 of Set 10 | listvyanka
# Processing Record 49 of Set 10 | vardo
# Processing Record 50 of Set 10 | la ronge
# Processing Record 1 of Set 11 | teguldet
# Processing Record 2 of Set 11 | ranong
# Processing Record 3 of Set 11 | machali
# Processing Record 4 of Set 11 | nelson bay
# Processing Record 5 of Set 11 | portpatrick
# City not found. Skipping...
# Processing Record 6 of Set 11 | cayenne
# Processing Record 7 of Set 11 | coahuayana
# Processing Record 8 of Set 11 | huaiyin
# Processing Record 9 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 11 | acapulco
# Processing Record 11 of Set 11 | kushima
# Processing Record 12 of Set 11 | barguzin
# Processing Record 13 of Set 11 | new philadelphia
# Processing Record 14 of Set 11 | thyboron
# Processing Record 15 of Set 11 | kalinovskoye
# Processing Record 16 of Set 11 | dno
# Processing Record 17 of Set 11 | te anau
# Processing Record 18 of Set 11 | coshocton
# Processing Record 19 of Set 11 | montabaur
# Processing Record 20 of Set 11 | ahipara
# Processing Record 21 of Set 11 | bushehr
# Processing Record 22 of Set 11 | coffs harbour
# Processing Record 23 of Set 11 | ibra
# Processing Record 24 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 11 | mikuni
# Processing Record 26 of Set 11 | puerto escondido
# Processing Record 27 of Set 11 | coihaique
# Processing Record 28 of Set 11 | saurimo
# Processing Record 29 of Set 11 | bougouni
# Processing Record 30 of Set 11 | mahajanga
# Processing Record 31 of Set 11 | buala
# Processing Record 32 of Set 11 | hilton head island
# Processing Record 33 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 34 of Set 11 | fasa
# Processing Record 35 of Set 11 | shakawe
# Processing Record 36 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 37 of Set 11 | wapakoneta
# Processing Record 38 of Set 11 | san cristobal
# Processing Record 39 of Set 11 | iracoubo
# Processing Record 40 of Set 11 | san policarpo
# Processing Record 41 of Set 11 | pudozh
# Processing Record 42 of Set 11 | marshalltown
# Processing Record 43 of Set 11 | kologriv
# Processing Record 44 of Set 11 | brewster
# Processing Record 45 of Set 11 | catarman
# Processing Record 46 of Set 11 | sao felix do xingu
# Processing Record 47 of Set 11 | babusnica
# Processing Record 48 of Set 11 | christchurch
# Processing Record 49 of Set 11 | kamsack
# Processing Record 50 of Set 11 | crotone
# Processing Record 1 of Set 12 | san jeronimo
# Processing Record 2 of Set 12 | yeppoon
# Processing Record 3 of Set 12 | jalu
# Processing Record 4 of Set 12 | suleja
# Processing Record 5 of Set 12 | rancho palos verdes
# Processing Record 6 of Set 12 | roald
# Processing Record 7 of Set 12 | saint-paul
# Processing Record 8 of Set 12 | pangody
# Processing Record 9 of Set 12 | moerai
# Processing Record 10 of Set 12 | abha
# Processing Record 11 of Set 12 | sinazongwe
# Processing Record 12 of Set 12 | tomatlan
# Processing Record 13 of Set 12 | sao miguel do araguaia
# Processing Record 14 of Set 12 | sulangan
# Processing Record 15 of Set 12 | rovinj
# Processing Record 16 of Set 12 | sur
# Processing Record 17 of Set 12 | nombre de dios
# Processing Record 18 of Set 12 | edd
# Processing Record 19 of Set 12 | rudnogorsk
# Processing Record 20 of Set 12 | gambiran
# Processing Record 21 of Set 12 | aklavik
# Processing Record 22 of Set 12 | korla
# Processing Record 23 of Set 12 | grinnell
# Processing Record 24 of Set 12 | khandyga
# Processing Record 25 of Set 12 | heihe
# Processing Record 26 of Set 12 | progreso
# Processing Record 27 of Set 12 | clyde
# Processing Record 28 of Set 12 | digras
# Processing Record 29 of Set 12 | gimbi
# Processing Record 30 of Set 12 | poronaysk
# Processing Record 31 of Set 12 | mount gambier
# Processing Record 32 of Set 12 | markova
# Processing Record 33 of Set 12 | wronki
# Processing Record 34 of Set 12 | gizo
# Processing Record 35 of Set 12 | havre-saint-pierre
# Processing Record 36 of Set 12 | banfora
# Processing Record 37 of Set 12 | pinczow
# Processing Record 38 of Set 12 | lampang
# Processing Record 39 of Set 12 | ekibastuz
# Processing Record 40 of Set 12 | constitucion
# Processing Record 41 of Set 12 | pedernales
# Processing Record 42 of Set 12 | kostomuksha
# Processing Record 43 of Set 12 | ballina
# Processing Record 44 of Set 12 | pacific grove
# Processing Record 45 of Set 12 | laguna
# Processing Record 46 of Set 12 | krasnoselkup
# Processing Record 47 of Set 12 | kangaatsiaq
# Processing Record 48 of Set 12 | onverwacht
# Processing Record 49 of Set 12 | sala consilina
# Processing Record 50 of Set 12 | callaway
# Processing Record 1 of Set 13 | arkadak
# Processing Record 2 of Set 13 | apaseo el alto
# Processing Record 3 of Set 13 | egvekinot
# Processing Record 4 of Set 13 | kutum
# Processing Record 5 of Set 13 | ust-kuyga
# Processing Record 6 of Set 13 | taga dzong
# City not found. Skipping...
# Processing Record 7 of Set 13 | hobyo
# Processing Record 8 of Set 13 | lamar
# Processing Record 9 of Set 13 | wahpeton
# Processing Record 10 of Set 13 | frutal
# Processing Record 11 of Set 13 | riberalta
# Processing Record 12 of Set 13 | sorland
# Processing Record 13 of Set 13 | charleville-mezieres
# Processing Record 14 of Set 13 | linxia
# Processing Record 15 of Set 13 | bluffton
# Processing Record 16 of Set 13 | pathein
# Processing Record 17 of Set 13 | colesberg
# Processing Record 18 of Set 13 | bonavista
# Processing Record 19 of Set 13 | lodja
# Processing Record 20 of Set 13 | talakan
# Processing Record 21 of Set 13 | opopeo
# Processing Record 22 of Set 13 | finschhafen
# Processing Record 23 of Set 13 | kasongo-lunda
# Processing Record 24 of Set 13 | khani
# Processing Record 25 of Set 13 | motygino
# Processing Record 26 of Set 13 | beaufort
# Processing Record 27 of Set 13 | winnemucca
# Processing Record 28 of Set 13 | jacareacanga
# Processing Record 29 of Set 13 | canico
# Processing Record 30 of Set 13 | jimeta
# Processing Record 31 of Set 13 | kununurra
# Processing Record 32 of Set 13 | plettenberg bay
# Processing Record 33 of Set 13 | greytown
# Processing Record 34 of Set 13 | armacao dos buzios
# City not found. Skipping...
# Processing Record 35 of Set 13 | nangong
# Processing Record 36 of Set 13 | taganak
# Processing Record 37 of Set 13 | kiunga
# Processing Record 38 of Set 13 | astana
# Processing Record 39 of Set 13 | ust-nera
# Processing Record 40 of Set 13 | hambantota
# Processing Record 41 of Set 13 | chihuahua
# Processing Record 42 of Set 13 | hovd
# Processing Record 43 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 13 | dunedin
# Processing Record 45 of Set 13 | santa maria
# Processing Record 46 of Set 13 | college
# Processing Record 47 of Set 13 | kadoma
# Processing Record 48 of Set 13 | antsohihy
# Processing Record 49 of Set 13 | eureka
# Processing Record 50 of Set 13 | qinzhou
# Processing Record 1 of Set 14 | oktyabrskiy
# Processing Record 2 of Set 14 | terney
# Processing Record 3 of Set 14 | bhigvan
# Processing Record 4 of Set 14 | okha
# Processing Record 5 of Set 14 | ahuimanu
# Processing Record 6 of Set 14 | tartus
# Processing Record 7 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 14 | malakisi
# City not found. Skipping...
# Processing Record 9 of Set 14 | praia
# Processing Record 10 of Set 14 | aitape
# Processing Record 11 of Set 14 | lata
# Processing Record 12 of Set 14 | xihe
# Processing Record 13 of Set 14 | hit
# Processing Record 14 of Set 14 | carndonagh
# Processing Record 15 of Set 14 | ternate
# Processing Record 16 of Set 14 | trujillo
# Processing Record 17 of Set 14 | batemans bay
# Processing Record 18 of Set 14 | chicontepec
# Processing Record 19 of Set 14 | buchanan
# Processing Record 20 of Set 14 | wamba
# Processing Record 21 of Set 14 | somerset
# Processing Record 22 of Set 14 | la florida
# Processing Record 23 of Set 14 | cheremukhovo
# Processing Record 24 of Set 14 | turka
# Processing Record 25 of Set 14 | manggar
# Processing Record 26 of Set 14 | asuncion
# Processing Record 27 of Set 14 | lompoc
# Processing Record 28 of Set 14 | broken hill
# Processing Record 29 of Set 14 | gonen
# Processing Record 30 of Set 14 | toulepleu
# City not found. Skipping...
# Processing Record 31 of Set 14 | poum
# Processing Record 32 of Set 14 | narok
# Processing Record 33 of Set 14 | xichang
# Processing Record 34 of Set 14 | sakakah
# Processing Record 35 of Set 14 | aleksandrov gay
# Processing Record 36 of Set 14 | urumqi
# Processing Record 37 of Set 14 | rabat
# Processing Record 38 of Set 14 | naryan-mar
# Processing Record 39 of Set 14 | whitley bay
# Processing Record 40 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 14 | loanda
# Processing Record 42 of Set 14 | kodinsk
# Processing Record 43 of Set 14 | sembakung
# Processing Record 44 of Set 14 | hamilton
# Processing Record 45 of Set 14 | susanville
# Processing Record 46 of Set 14 | paciran
# Processing Record 47 of Set 14 | maumere
# Processing Record 48 of Set 14 | omsukchan
# Processing Record 49 of Set 14 | labytnangi
# Processing Record 50 of Set 14 | gasa
# Processing Record 1 of Set 15 | chicama
# Processing Record 2 of Set 15 | zarubino
# Processing Record 3 of Set 15 | mirabad
# Processing Record 4 of Set 15 | cervo
# Processing Record 5 of Set 15 | shwebo
# Processing Record 6 of Set 15 | zhitikara
# City not found. Skipping...
# Processing Record 7 of Set 15 | nynashamn
# Processing Record 8 of Set 15 | zyryanka
# Processing Record 9 of Set 15 | bathurst
# Processing Record 10 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 11 of Set 15 | ziro
# Processing Record 12 of Set 15 | shingu
# Processing Record 13 of Set 15 | bon air
# Processing Record 14 of Set 15 | port shepstone
# Processing Record 15 of Set 15 | altamirano
# Processing Record 16 of Set 15 | manturovo
# Processing Record 17 of Set 15 | kolosovka
# Processing Record 18 of Set 15 | korop
# Processing Record 19 of Set 15 | copiapo
# Processing Record 20 of Set 15 | hervey bay
# Processing Record 21 of Set 15 | petatlan
# Processing Record 22 of Set 15 | warangal
# Processing Record 23 of Set 15 | lagoa
# Processing Record 24 of Set 15 | gambela
# Processing Record 25 of Set 15 | arlit
# Processing Record 26 of Set 15 | kobryn
# Processing Record 27 of Set 15 | olga
# Processing Record 28 of Set 15 | ijuin
# Processing Record 29 of Set 15 | dengzhou
# Processing Record 30 of Set 15 | timra
# Processing Record 31 of Set 15 | port augusta
# Processing Record 32 of Set 15 | sekoma
# Processing Record 33 of Set 15 | biak
# Processing Record 34 of Set 15 | jose de freitas
# Processing Record 35 of Set 15 | aripuana
# Processing Record 36 of Set 15 | manta
# Processing Record 37 of Set 15 | voyvozh
# Processing Record 38 of Set 15 | oskemen
# Processing Record 39 of Set 15 | north platte
# Processing Record 40 of Set 15 | nova olinda do norte
# Processing Record 41 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 15 | finote selam
# Processing Record 43 of Set 15 | lanivtsi
# Processing Record 44 of Set 15 | cleethorpes
# Processing Record 45 of Set 15 | acari
# Processing Record 46 of Set 15 | el rosario
# Processing Record 47 of Set 15 | herat

# %%
# Add the data to a list in a dict then at the DF
len(city_data)
# Out:
# 694

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Upernavik      GL  72.7868  -56.1549     16.29        98         100
# 1    Yenagoa      NG   4.9247    6.2642     77.77        90         100
# 2  Cape Town      ZA -33.9258   18.4232     58.12        87          43
# 3  Busselton      AU -33.6500  115.3333     66.31        53          99
# 4      Kalat      PK  29.0225   66.5916     58.19        23         100
#
#    Wind Speed Current Description
# 0        4.12     overcast clouds
# 1        4.85     overcast clouds
# 2        3.00          light rain
# 3        7.76     overcast clouds
# 4        3.78     overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "weather_database/WeatherPy_Database.csv"

# %%
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
